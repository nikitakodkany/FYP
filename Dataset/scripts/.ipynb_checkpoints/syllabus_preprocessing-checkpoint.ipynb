# %%
#Libraries
import pandas as pd

# %%
data = pd.read_csv("/home/nikita/College/FYP/Dataset//dataset/Syllabus_Dataset.csv")
print(data)
# Out:
#                                          SyllabusKeys  \
# 0                Formal Languages and Automata Theory
# 1                              Data Structures with C
# 2                                 Digital Electronics
# 3               Object Oriented Programming with Java
# 4                               Computer Organization
# 5                                     Web Programming
# 6                  Data Structures with C\nLaboratory
# 7    Object Oriented Programming with Java Laboratory
# 8   Discrete Mathematical Structures and Graph Theory
# 9                                    Operating System
# 10                         Database Management System
# 11                   Design and Analysis of Algorithm
# 12                               Software Engineering
# 13                                 Python Programming
# 14                              Algorithms Laboratory
# 15                   Database Applications Laboratory
# ...
